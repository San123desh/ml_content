# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#FUNCTIONAL
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title',fontdict={'fontname':'Comic Sans MS','fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# OO
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# __plot appearance__

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
# ax.plot(x,y,color = 'green',lw=3,alpha = 0.5,linestyle='-.') #rgb hex code
ax.plot(x,y,color = 'brown',lw = 1,ls='-',marker = 'o',markersize=10,
       markerfacecolor='yellow',markeredgewidth=2,markeredgecolor='aqua')

# %% [markdown]
# x

# %%
len(x)
# Out:
# 11

# %% [markdown]
# __control over axis appearance & plot range__

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = 'brown',lw = 1,ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])#upperbound
# Out:
# (0.0, 2.0)

# %% [markdown]
# __special plot types__

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,999),99)
plt.hist(data)
# Out:
# (array([ 6., 13.,  9., 16., 12.,  7.,  8.,  9.,  9., 10.]),
#  array([  5. ,  98.8, 192.6, 286.4, 380.2, 474. , 567.8, 661.6, 755.4,
#         849.2, 943. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

#rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# __Exercises__

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')

ax.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# __create a figure object and put two axes on it, ax1 and ax2.located at[0,0,1,1]
# and [0.2,0.5,.2,.2] respectively__

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,.5,.2,.2])

ax1.plot(x,y,color='red')
ax2.plot(x,y,color='blue')

# %% [markdown]
# __create the plot by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4] & use x,y,and z arrays to recreate the plot below.Notice the xlimits and y limits on the inserted plot:__

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([.2,.5,.4,.4])

#large
ax.plot(x,z)
ax.set_xlabel('X')
ax.set_ylabel('Z')

#insert
ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30.0, 50.0)

# %% [markdown]
# __use plt.subplots(nrows=1,ncols=2) to create the plot below, Now plot(x,y) and (x,z) on the axes. Play around with the linewidth and style & see if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code__

# %%
fig,axes = plt.subplots(1,2,figsize=(12,2))

axes[0].plot(x,y,color='blue',ls = '--',lw = 3)
axes[1].plot(x,y,z,color='red',lw=3)
